# %%
import pandas as pd
import numpy as np

# %%
names = ["Gemeentecode", "GemeentecodeGM",	"Gemeentenaam",	"Provinciecode", "ProvinciecodePV",	"Provincienaam"]
gemeente_codes = pd.read_csv("./data/gemeente_codes.csv", names=names) # read csv file, specified encoding
gemeente_codes
# Out:
#      Gemeentecode  GemeentecodeGM     Gemeentenaam  Provinciecode  \
# 0    Gemeentecode  GemeentecodeGM     Gemeentenaam  Provinciecode
# 1            1680          GM1680      Aa en Hunze             22
# 2            0358          GM0358         Aalsmeer             27
# 3            0197          GM0197           Aalten             25
# 4            0059          GM0059    Achtkarspelen             21
# ..            ...             ...              ...            ...
# 338          0879          GM0879          Zundert             30
# 339          0301          GM0301          Zutphen             25
# 340          1896          GM1896  Zwartewaterland             23
# 341          0642          GM0642      Zwijndrecht             28
# 342          0193          GM0193           Zwolle             23
#
#      ProvinciecodePV  Provincienaam
# 0    ProvinciecodePV  Provincienaam
# 1               PV22        Drenthe
# 2               PV27  Noord-Holland
# ...

# %%
names = ["ID", "Woningkenmerken", "RegioS", "Perioden", "GemiddeldAardgasverbruik_1", "GemiddeldElektriciteitsverbruik_2", "Stadsverwarming_3"]
gemeente_verbruik = pd.read_csv("./data/verbruik_per_gemeente.csv", names=names, sep=';') # read csv file, specified encoding
gemeente_verbruik
# Out:
#           ID  Woningkenmerken  RegioS  Perioden  GemiddeldAardgasverbruik_1  \
# 0         ID  Woningkenmerken  RegioS  Perioden  GemiddeldAardgasverbruik_1
# 1        216          T001100  GM1680  2010JJ00                        2700
# 2        217          T001100  GM1680  2011JJ00                        2100
# 3        218          T001100  GM1680  2012JJ00                        2300
# 4        219          T001100  GM1680  2013JJ00                        2400
# ...      ...              ...     ...       ...                         ...
# 44060  51667          1014850  GM1979  2017JJ00                         NaN
# 44061  51668          1014850  GM1979  2018JJ00                         NaN
# 44062  51669          1014850  GM1979  2019JJ00                         NaN
# 44063  51670          1014850  GM1979  2020JJ00                         NaN
# 44064  51671          1014850  GM1979  2021JJ00                        1320
#
# ...
